# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('arrival_rate.csv')

plt.plot(df['0'], df['1'])
plt.title("Performance of TCP Server")
plt.ylabel("Response Time")
plt.xlabel("Arrival Rate")
# Out:
# Text(0.5, 0, 'Arrival Rate')
